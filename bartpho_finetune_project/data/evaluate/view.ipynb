# %%
import pandas as pd

# %%
df = pd.read_csv('output_predicted_evaluated.csv')
df.head()
# Out:
#                                                 text  \
# 0  \nSau bài thi ngắn năm mươi phút và bốn mươi c...
# 1  Với doanh thu bình quân 200 USD/TEU, theo số l...
# 2  Tôi có một shop hoa. Ngày Phụ nữ Việt Nam luôn...
# 3  Nhưng ông nông dân miệt vườn này vẫn điềm tĩnh...
# 4  George Black lặng lẽ khóc, khi nghe bác sĩ Bản...
#
#                                              summary  \
# 0  Đại thụ của nền sử học ra đi, để lại cho cuộc ...
# 1  Với doanh thu bình quân 200 USD/TEU, theo số l...
# 2  Chỉ là bởi giữa lúc ngập tràn trên mạng xã hội...
# 3  Các nhà khoa học nhận diện, hiện tượng "ngập t...
# 4  Ông rất tâm huyết với công cuộc hòa giải và hà...
#
#                                         summary_pred   ROUGE-1   ROUGE-2  \
# 0  Trong bốn mươi câu trắc nghiệm lịch sử sáng na...  0.755716  0.607961
# 1  Với doanh thu bình quân 200 USD/TEU, theo số l...  0.706024  0.567633
# 2  Chỉ là bởi giữa lúc ngập tràn trên mạng xã hội...  0.637135  0.594901
# ...
