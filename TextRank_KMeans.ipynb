# %%
# Text Rank

# %%
# !pip install rouge_score
# Out:
# Requirement already satisfied: rouge_score in /usr/local/lib/python3.12/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rouge_score) (2.0.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (4.67.1)

# %%
import numpy as np
import pandas as pd
import re
from rouge_score import rouge_scorer

# %%
def split_sentences(text):
    sentences = re.split(r'[.!?]', text)
    sentences = [s.strip() for s in sentences if s.strip()]
    return sentences

# %%
def sentence_similarity(s1, s2):
    words1 = set(s1.lower().split())
    words2 = set(s2.lower().split())
    if len(words1) == 0 or len(words2) == 0:
        return 0
    return len(words1 & words2) / (np.log(len(words1)+1) + np.log(len(words2)+1))

# %%
def build_similarity_matrix(sentences):
    n = len(sentences)
    sim_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            if i != j:
                sim_matrix[i][j] = sentence_similarity(sentences[i], sentences[j])
    return sim_matrix

# %%
def pagerank(sim_matrix, eps=0.0001, d=0.85):
    n = sim_matrix.shape[0]
    scores = np.ones(n) / n
    row_sum = sim_matrix.sum(axis=1)
    row_sum[row_sum == 0] = 1
    while True:
        new_scores = (1 - d) / n + d * sim_matrix.T.dot(scores / row_sum)
        if np.linalg.norm(new_scores - scores) < eps:
            break
        scores = new_scores
    return scores

# %%
def textrank(text, top_n=2):
    sentences = split_sentences(text)
    if len(sentences) == 0:
        return ""
    sim_matrix = build_similarity_matrix(sentences)
    scores = pagerank(sim_matrix)
    ranked = np.argsort(scores)[::-1]
    summary = [sentences[i] for i in ranked[:min(top_n, len(sentences))]]
    return ". ".join(summary) + "."

# %%
def evaluate_summaries(df):
    scorer = rouge_scorer.RougeScorer(['rouge1','rouge2','rougeL'], use_stemmer=True)
    results = []
    for _, row in df.iterrows():
        reference = row["Summarize"]
        generated = row["summary_pred"]
        score = scorer.score(reference, generated)
        results.append(score)
    return results

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/datasets/Nhap_mon_AI/datadone.csv", encoding='utf-8')

df = df.iloc[:10, :]

df = df.dropna(subset=["Content"])

df["summary_pred"] = df["Content"].apply(lambda x: textrank(str(x), top_n=3))

scores = evaluate_summaries(df)

print(df)
print("\nĐiểm ROUGE:", scores)
# Out:
#                                                 Link  \
# 0  https://vnexpress.net/suat-hoc-va-con-ca-46266...
# 1  https://vnexpress.net/du-hoc-de-lao-dong-chui-...
# 2  https://vnexpress.net/ha-noi-co-rung-4625687.html
# 3  https://vnexpress.net/quyen-tu-quyet-rut-bao-h...
# 4  https://vnexpress.net/tro-choi-chung-minh-tai-...
# 5  https://vnexpress.net/do-tien-xuong-bien-46243...
# 6  https://vnexpress.net/gianh-viec-tu-tay-robot-...
# 7  https://vnexpress.net/kiem-tien-tu-dat-4623773...
# 8  https://vnexpress.net/streamer-chan-dat-462346...
# 9  https://vnexpress.net/nguoi-nuoc-ngoai-mua-nha...
#
#                              Title                Category             Author  \
# 0               Suất học và con cá     Giáo dục & tri thức       Võ Nhật Vinh
# 1        Du học để lao động 'chui'     Giáo dục & tri thức   Nguyễn Nam Cường
# 2                   Hà Nội có rừng  Chính trị & chính sách  Phạm Hoàng Phương
# 3    Quyền tự quyết 'rút bảo hiểm'  Chính trị & chính sách           Lê Tuyết
# 4  'Trò chơi' chứng minh tài chính   Kinh doanh & quản trị             Hải Lý
# 5               Đổ tiền xuống biển   Kinh doanh & quản trị            Bùi Mẫn
# 6          Giành việc từ tay robot     Giáo dục & tri thức         Ngô Di Lân
# 7                 Kiếm tiền từ đất   Kinh doanh & quản trị       Đặng Hùng Võ
# 8              Streamer 'chân đất'   Kinh doanh & quản trị   Nguyễn Nam Cường
# 9         Người nước ngoài mua nhà   Kinh doanh & quản trị   Hoàng Văn Phương
#
#                                          Description  \
# 0  Điều gì phía sau câu chuyện khổ tâm của những ...
# 1  Tờ mờ sáng, nhiều người còn ngủ say thì Thái, ...
# 2  Do điều kiện khác biệt của Hà Nội, việc áp dụn...
# 3  Bảo hiểm xã hội không phải là ngân hàng; cho p...
# 4  Chủ đầu tư hết tiền, căn hộ 5 tỷ đồng chị Than...
# 5  Không có 'rác' hoặc 'phế thải', mọi thứ đều hữ...
# 6  Lần đầu bước chân vào nhà hàng Spyce ở thành p...
# 7  Nguồn thu từ đất ở Việt Nam chủ yếu đến từ cơ ...
# 8  Các 'streamer nông dân' thu hoạch cây trái, nấ...
# 9  Nhu cầu ngày càng tăng của người nước ngoài về...
#
#                                              Content  \
# 0  Sau này lớn lên, gặp mỗi dịp giảm giá lớn, tôi...
# 1  Cậu nhận "théc-be" (phân loại, bốc xếp hàng hó...
# 2  Ý tưởng "rừng trong đô thị" có thể hiểu đơn gi...
# 3  Lúc đó, tôi đồng tình với suy nghĩ "quyền tự q...
# 4  Theo hướng dẫn của nhân viên môi giới, chị ký ...
# 5  Ngoài yếu tố môi trường, điều làm tôi chú ý là...
# 6  Không ai đón tôi ở cửa, cũng không ai hướng dẫ...
# 7  Lúc đó tôi ở vị trí cấp phó phụ trách kỹ thuật...
# 8  Họ cầm từng trái cà chua, ớt chuông giới thiệu...
# 9  Nền kinh tế toàn cầu ngày càng hội nhập, thể h...
#
#                           Career  \
# 0                     Giảng viên
# 1            Thạc sĩ, giảng viên
# 2   Kiến trúc sư, nhà nghiên cứu
# 3                        Nhà báo
# 4                        Nhà báo
# 5                  Kỹ sư cao cấp
# 6  Tiến sĩ ngành Quan hệ Quốc tế
# 7  Chuyên gia Quản lý tài nguyên
# 8            Thạc sĩ, giảng viên
# 9                Tiến sĩ Kinh tế
#
#                                            Summarize  \
# 0  Nhưng đó đều có thể là những lựa chọn bất đắc ...
# 1  Thái tranh thủ thời gian hết mức có thể để kiế...
# 2  Tại thủ đô của nhiều quốc gia phát triển, khôn...
# 3  Bảo hiểm xã hội dù là bắt buộc, nhà nước dù xu...
# 4  Nhân viên môi giới nói ngân hàng cho chị vay b...
# 5  là minh chứng cho khả năng khai thác và tận dụ...
# 6  Do đó, để bảo vệ được bản thân và những người ...
# 7  Thu từ các loại thuế liên quan đến đất đạt 3.2...
# 8  Người xem livestream, dù không ngửi được mùi t...
# 9  Do đó, khơi thông được nguồn cung một cách liê...
#
#                                         summary_pred
# 0  Nếu số liệu chỉ rõ, cuộc tranh giành suất học ...
# 1  Chấp nhận làm "chui", vượt quá quy định 20 tiế...
# 2  Dù diện tích nội đô trên tổng diện tích toàn đ...
# 3  Nếu chúng ta ủng hộ quyền tự quyết rút bảo hiể...
# 4  Công ty trung gian cam kết quản lý tiền đặt cọ...
# 5  Các bãi tập kết này được thiết kế hệ thống tho...
# 6  Tuy nhiên, trong bối cảnh đa số phần mềm AI đã...
# 7  Để cải cách, chúng ta phải giải quyết xong ba ...
# 8  Đây là một gợi ý để không chỉ người dân Bắc Gi...
# 9  Khi cơ sở dữ liệu nhà ở quốc gia được hoàn thà...
#
# Điểm ROUGE: [{'rouge1': Score(precision=0.9878542510121457, recall=0.4468864468864469, fmeasure=0.6153846153846154), 'rouge2': Score(precision=0.9227642276422764, recall=0.41651376146788993, fmeasure=0.5739570164348926), 'rougeL': Score(precision=0.8097165991902834, recall=0.3663003663003663, fmeasure=0.5044136191677175)}, {'rouge1': Score(precision=0.949748743718593, recall=0.40471092077087795, fmeasure=0.5675675675675677), 'rouge2': Score(precision=0.6818181818181818, recall=0.28969957081545067, fmeasure=0.4066265060240964), 'rougeL': Score(precision=0.6984924623115578, recall=0.29764453961456105, fmeasure=0.41741741741741745)}, {'rouge1': Score(precision=0.9098837209302325, recall=0.6493775933609959, fmeasure=0.7578692493946732), 'rouge2': Score(precision=0.6122448979591837, recall=0.4365904365904366, fmeasure=0.5097087378640777), 'rougeL': Score(precision=0.5813953488372093, recall=0.4149377593360996, fmeasure=0.4842615012106538)}, {'rouge1': Score(precision=1.0, recall=0.21345707656612528, fmeasure=0.35181644359464626), 'rouge2': Score(precision=0.994535519125683, recall=0.21138211382113822, fmeasure=0.3486590038314176), 'rougeL': Score(precision=0.7934782608695652, recall=0.16937354988399073, fmeasure=0.2791586998087954)}, {'rouge1': Score(precision=1.0, recall=0.4077490774907749, fmeasure=0.5792922673656619), 'rouge2': Score(precision=1.0, recall=0.4066543438077634, fmeasure=0.5781865965834428), 'rougeL': Score(precision=1.0, recall=0.4077490774907749, fmeasure=0.5792922673656619)}, {'rouge1': Score(precision=1.0, recall=0.34782608695652173, fmeasure=0.5161290322580645), 'rouge2': Score(precision=0.933579335793358, recall=0.323943661971831, fmeasure=0.48098859315589354), 'rougeL': Score(precision=0.8161764705882353, recall=0.28388746803069054, fmeasure=0.42125237191650855)}, {'rouge1': Score(precision=0.9384615384615385, recall=0.7283582089552239, fmeasure=0.8201680672268907), 'rouge2': Score(precision=0.7606177606177607, recall=0.5898203592814372, fmeasure=0.6644182124789207), 'rougeL': Score(precision=0.6923076923076923, recall=0.5373134328358209, fmeasure=0.6050420168067226)}, {'rouge1': Score(precision=1.0, recall=0.3981358189081225, fmeasure=0.5695238095238095), 'rouge2': Score(precision=0.9932885906040269, recall=0.39466666666666667, fmeasure=0.564885496183206), 'rougeL': Score(precision=0.7759197324414716, recall=0.30892143808255657, fmeasure=0.44190476190476186)}, {'rouge1': Score(precision=0.9715639810426541, recall=0.39272030651340994, fmeasure=0.5593451568894953), 'rouge2': Score(precision=0.8047619047619048, recall=0.32437619961612285, fmeasure=0.46238030095759236), 'rougeL': Score(precision=0.6492890995260664, recall=0.2624521072796935, fmeasure=0.373806275579809)}, {'rouge1': Score(precision=0.9819819819819819, recall=0.49099099099099097, fmeasure=0.6546546546546547), 'rouge2': Score(precision=0.8914027149321267, recall=0.44469525959367945, fmeasure=0.5933734939759037), 'rougeL': Score(precision=0.8648648648648649, recall=0.43243243243243246, fmeasure=0.5765765765765767)}]
